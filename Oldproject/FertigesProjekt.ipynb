# %%
#Englischtraining Quiz Lektion 1

#Quiz starten mit Frage, ja oder nein Eingabe, Bei ja werden Regeln angezeigt und erste Frage beginnt

#Eingabe für eine Frage erzeugen
answer = input("Bereit für die erste Runde? ja oder nein?")

#Wenn mit ja geantwortet wird, beginnt die erste Frage, bei nein passiert nichts
if answer == "ja":
    print("Los gehts! Regeln: Wenn du die Frage beim ersten Mal richtig löst, erhältst du einen Punkt, beim zweiten Mal einen halben Punkt und beim dritten Mal 0 Punkte")

#Die Punkteregeln und die erste Frage wird angezeigt

#Erste Frage

    punkte = 0                                                           #Punktestart bei 0
    answer = input("Was heißt Baum auf Englisch?")                       #Frage mit Eingabefeld für Text
    if answer == "tree":                                                 #Die richtige Antwort lautet tree, Wenn Antwort richig, dann:
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zu Frage 2
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist t")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Baum auf Englisch?")                   #Frage mit Eingabefeld für Text
        if answer == "tree":                                             #Wenn Antwort identisch mit tree, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zu Frage 2
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt
            print("Nein! Das Wort hat vier Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Was heißt Baum auf Englisch?")               #Frage mit Eingabefeld für Text
            if answer == "tree":                                         #Wenn die Antwort im Eingabefeld tree ist dann
                print("Richtig!")                                        #Angezeigter Text Richtig! und weiter zu Frage 2
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet tree")                #Wird Lösung angezeigt  
                answer = input("Was heißt Baum auf Englisch")            #Frage mit Eingabefeld für Text
                if answer == "tree":                                     #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zu Frage 2
#Zweite Frage
                
    answer = input("Was heißt Hund auf Englisch?")                       #Frage mit Eingabefeld für Text
    if answer == "dog":                                                  #Die richtige Antwort lautet dog, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zu Frage 3
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist d")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Baum auf Englisch?")                   #Frage mit Eingabefeld für Text
        if answer == "dog":                                              #Wenn Antwort identisch mit dog, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zu Frage 3
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt
            print("Nein! Das Wort hat drei Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Was heißt Hund auf Englisch?")               #Frage mit Eingabefeld für Text
            if answer == "dog":                                          #Wenn Antwort identisch mit dog, dann weiter zu Frage 3
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet dog")                 #Wird Lösung angezeigt  
                answer = input("Was heißt Baum auf Englisch")            #Richtige Antwort muss eingegeben werden
                if answer == "dog":                                      #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zu Frage 3    
#Dritte Frage

    answer = input("Wie heißt die Farbe Weiß auf Englisch?")             #Frage mit Eingabefeld für Text
    if answer == "white":                                                #Die richtige Antwort lautet white, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zu Frage 4
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist w")     #Text mit Tipp wird angezeigt
        answer = input("Wie heißt die Farbe Weiß auf Englisch?")         #Frage mit Eingabefeld für Text
        if answer == "white":                                            #Wenn Antwort identisch mit white, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zu Frage 4
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt
            print("Nein! Das Wort hat fünf Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Wie heißt die Farbe Weiß auf Englisch?")     #Frage mit Eingabefeld für Text
            if answer == "white":                                        #Wenn Antwort identisch mit white, dann nächster Schritt
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet white")               #Wird Lösung angezeigt  
                answer = input("Wie heißt die Farbe Weiß auf Englisch?") #Richtige Antwort muss eingegeben werden
                if answer == "white":                                    #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zu Frage 4        
#Vierte Frage

    answer = input("Was heißt Spiel auf Englisch?")                      #Frage mit Eingabefeld für Text
    if answer == "game":                                                 #Die richtige Antwort lautet game, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zur Punkteauswertung
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist g")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Spiel auf Englisch?")                  #Frage mit Eingabefeld für Text
        if answer == "game":                                             #Wenn Antwort identisch mit game, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zur Punkteauswertung
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
            print("Nein! Das Wort hat vier Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Was heißt Spiel auf Englisch?")              #Frage mit Eingabefeld für Text
            if answer == "game":                                         #Wenn Antwort identisch mit game, dann nächster Schritt
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet game")                #Wird Lösung angezeigt  
                answer = input("Was heißt Spiel auf Englisch?")          #Richtige Antwort muss eingegeben werden
                if answer == "game":                                     #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zur Punkteauswertung              
                        
#Fünfte Frage

    answer = input("Was heißt Schwarz auf Englisch?")                    #Frage mit Eingabefeld für Text
    if answer == "black":                                                #Die richtige Antwort lautet black, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zur Punkteauswertung
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist b")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Schwarz auf Englisch?")                #Frage mit Eingabefeld für Text
        if answer == "black":                                            #Wenn Antwort identisch mit black, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zur Punkteauswertung
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
            print("Nein! Das Wort hat fünf Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Was heißt Schwarz auf Englisch?")            #Frage mit Eingabefeld für Text
            if answer == "black":                                        #Wenn Antwort identisch mit black, dann nächster Schritt
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet black")               #Wird Lösung angezeigt  
                answer = input("Was heißt Schwarz auf Englisch?")        #Richtige Antwort muss eingegeben werden
                if answer == "black":                                    #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zur Punkteauswertung                         
#Sechste Frage
    answer = input("Was heißt Flasche auf Englisch?")                    #Frage mit Eingabefeld für Text
    if answer == "bottle":                                               #Die richtige Antwort lautet bottle, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zur Punkteauswertung
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist b")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Flasche auf Englisch?")                #Frage mit Eingabefeld für Text
        if answer == "bottle":                                           #Wenn Antwort identisch mit bottle, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zur Punkteauswertung
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
            print("Nein! Das Wort hat sechs Buchstaben")                 #Text mit Tipp wird angezeigt
            answer = input("Was heißt Flasche auf Englisch?")            #Frage mit Eingabefeld für Text
            if answer == "bottle":                                       #Wenn Antwort identisch mit bottle, dann nächster Schritt
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet bottle")              #Wird Lösung angezeigt  
                answer = input("Was heißt Flasche auf Englisch?")        #Richtige Antwort muss eingegeben werden
                if answer == "bottle":                                   #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zur Punkteauswertung                      
#Siebte Frage
    answer = input("Was heißt Schlange auf Englisch?")                   #Frage mit Eingabefeld für Text
    if answer == "snake":                                                #Die richtige Antwort lautet snake, Wenn Antwort richig, dann:  
        print("Richtig!")                                                #Angezeigter Text Richtig!
        punkte +=1                                                       #Dem Punktestand wird ein Punkt addiert und weiter zur Punkteauswertung
    else:                                                                #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
        print("Probier es nochmal! Tipp: Der erste Buchstabe ist s")     #Text mit Tipp wird angezeigt
        answer = input("Was heißt Schlange auf Englisch?")               #Frage mit Eingabefeld für Text
        if answer == "snake":                                            #Wenn Antwort identisch mit snake, dann nächster Schritt
            print("Richtig!")                                            #Angezeigter Text Richtig!
            punkte +=0.5                                                 #Halber Punkt addiert zum Punktestand und weiter zur Punkteauswertung
        else:                                                            #Ansonsten bei falscher Antwort: wird folgendes angezeigt 
            print("Nein! Das Wort hat fünf Buchstaben")                  #Text mit Tipp wird angezeigt
            answer = input("Was heißt Schlange auf Englisch?")           #Frage mit Eingabefeld für Text
            if answer == "snake":                                        #Wenn Antwort identisch mit snake, dann nächster Schritt
                print("Richtig!")                                        #Angezeigter Text Richtig!
            else:                                                        #Ansonsten, wenn Antwort wieder nicht richtig
                print("Die richtige Antwort lautet snake")               #Wird Lösung angezeigt  
                answer = input("Was heißt Schlange auf Englisch?")       #Richtige Antwort muss eingegeben werden
                if answer == "snake":                                    #Wenn nun richtige Antwort eingegeben wurde
                    print("Richtig!")                                    #Angezeigter Text Richtig!
                                                                         #Punkt wird nicht aufgezählt, da 0 Punkte erhalten werden, weiter zur Punkteauswertung                      
   
    #Ergebnis und Ende des Tests  

    #Import Random für die Einführung zufälliger Listen
    import random
    #Sentence für drei gesammelte unterschiedliche Sätze als Liste
    sentence = ['Glückwunsch! Dein Punktestand ist:', 'So viel Punkte hast du gesammelt:', 'Sehr schön! Hier sind deine Punkte: ']
    #Choice wählt ein zufälliges Element aus der Liste sentence
    choice = random.choice(sentence)
    #Und zeigt den ausgewählten Satz mit der Summe der Punkte
    print(choice + str(punkte))

    #Mathematische Operation der Punkte in Prozentzahl
    #Die gesammelten Punkte, also die Summe wird durch die Anzahl der Fragen dividiert und mit *100 multipliziert
    prozent = (punkte/7)*100
    
    #Das Ergebnis wird im angezeigten Text angezeigt mit str(punkte)
    print("Von 100% hast du  " , prozent , "% richtig")

#Ende
# Out:
# Bereit für die erste Runde? ja oder nein?ja
# Los gehts! Regeln: Wenn du die Frage beim ersten Mal richtig löst, erhältst du einen Punkt, beim zweiten Mal einen halben Punkt und beim dritten Mal 0 Punkte
# Was heißt Baum auf Englisch?tree
# Richtig!
# Was heißt Hund auf Englisch?dog
# Richtig!
# Wie heißt die Farbe Weiß auf Englisch?white
# Richtig!
# Was heißt Spiel auf Englisch?game
# Richtig!
# Was heißt Schwarz auf Englisch?sch
# Probier es nochmal! Tipp: Der erste Buchstabe ist b
# Was heißt Schwarz auf Englisch?black
# Richtig!
# Was heißt Flasche auf Englisch?bottle
# Richtig!
# Was heißt Schlange auf Englisch?snale
# Probier es nochmal! Tipp: Der erste Buchstabe ist s
# Was heißt Schlange auf Englisch?sna
# Nein! Das Wort hat fünf Buchstaben
# Was heißt Schlange auf Englisch?snake
# Richtig!
# Glückwunsch! Dein Punktestand ist:5.5
# Von 100% hast du   78.57142857142857 % richtig
